# %%
#import the file and open it  
import pandas as pd 
dataset = pd.read_excel("3. Descriptive Statistics.xlsx",sheet_name=0)

# %%
dataset.head()  #prints first 5 entries
# Out:
#    ID Gender           Birth Date  Education  JobCategory  CurrentSalary  \
# 0   3      f           07/26/1929         12            1          21450
# 1   4      f           04/15/1947          8            1          21900
# 2   8      f  1966-06-05 00:00:00         12            1          21900
# 3   9      f           01/23/1946         15            1          27900
# 4  10      f           02/13/1946         12            1          24000
#
#    After6Months  SalBegin  Job Time  Prev Exep  Minority
# 0       16725.0     12000        98        381         0
# 1       17550.0     13200        98        190         0
# 2       15825.0      9750        98          0         0
# 3       20325.0     12750        98        115         0
# 4       18750.0     13500        98        244         0

# %%
dataset['CurrentSalary'].mean()
# Out:
# 34419.56751054852

# %%
dataset['CurrentSalary'].mode()
# Out:
# 0    30750
# dtype: int64

# %%
dataset['CurrentSalary'].median()
# Out:
# 28875.0

# %%
dataset['CurrentSalary'].describe()
# Out:
# count       474.000000
# mean      34419.567511
# std       17075.661465
# min       15750.000000
# 25%       24000.000000
# 50%       28875.000000
# 75%       36937.500000
# max      135000.000000
# Name: CurrentSalary, dtype: float64

# %%
dataset['CurrentSalary'].skew()
# Out:
# 2.1246062823682506

# %%
dataset['CurrentSalary'].kurt()
# Out:
# 5.377822396136782

# %%
import matplotlib.pyplot as plt
plt.boxplot(dataset['CurrentSalary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1710fcdab48>,
#   <matplotlib.lines.Line2D at 0x1710fcdafc8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1710fcdacc8>,
#   <matplotlib.lines.Line2D at 0x1710fce2dc8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1710fcc8dc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1710fce2ec8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1710fcd4888>],
#  'means': []}

# %%
plt.scatter(dataset['CurrentSalary'],dataset['After6Months'])
